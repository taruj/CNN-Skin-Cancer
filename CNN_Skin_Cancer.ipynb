# %% [markdown]
# <a href="https://colab.research.google.com/github/taruj/CNN-Skin-Cancer/blob/main/CNN_Skin_Cancer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis. <p>
# Two hash signs are Custom Comments ## <p>
# Blue text is for inference and notes <font color="darkblue"> Inference and Notes

# %% [markdown]
# ### Importing Skin Cancer Data
# #### To do: Take necessary actions to read the data

# %% [markdown]
# ### Importing all the important libraries

# %%
import numpy as np
import pandas as pd
import os
import PIL

import pathlib
import tensorflow as tf

import matplotlib.pyplot as plt

from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Rescaling, Conv2D, BatchNormalization, MaxPooling2D, Dropout, Flatten, Dense
from keras.optimizers import adam_v2
from tensorflow.keras import layers, Sequential
from tensorflow.keras.utils import plot_model

# %%
## If you are using the data by mounting the google drive, use the following :
from google.colab import drive
drive.mount('/content/gdrive')

##Ref:https://towardsdatascience.com/downloading-datasets-into-google-drive-via-google-colab-bcb1b30b0166
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
## Define the paths of the train and test dataset
root_path = "/content/gdrive/MyDrive/Colab Notebooks/data/Skin_Cancer"
dir_train = pathlib.Path(root_path + "/Train")
dir_test = pathlib.Path(root_path + "/Test")
print("data_dir_train: ", dir_train, "\ndata_dir_test: ", dir_test)
# Out:
# data_dir_train:  /content/gdrive/MyDrive/Colab Notebooks/data/Skin_Cancer/Train
# data_dir_test:  /content/gdrive/MyDrive/Colab Notebooks/data/Skin_Cancer/Test

# %%
## Get details of the files in the path
image_count_train = len(list(dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(dir_test.glob('*/*.jpg')))
<print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# <font color="darkblue"> 2239 image files in Train Data Set Folder <p>
# 118 image files in Test Data Set Folder

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
## Create Variables for batch size, image height and image width 
## Standardization
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
# creating train dataset here
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    dir_train,
    seed=123,
    validation_split= 0.2,
    subset='training',
    image_size=(img_height,img_width),
    batch_size=batch_size
)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
# creating validation dataset here
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    dir_train,
    seed=123,
    validation_split= 0.2,
    subset='validation',
    image_size=(img_height,img_width),
    batch_size=batch_size
)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
## for test set , creating only 1 batch
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    dir_test,
    seed=123,
    batch_size=118,
    image_size=(img_height,img_width)
)
# Out:
# Found 118 files belonging to 9 classes.

# %%
type(test_ds)
# Out:
# tensorflow.python.data.ops.dataset_ops.BatchDataset

# %%
# List out all the classes of skin cancer and store them in a list. 
# You can find the class names in the class_names attribute on these datasets. 
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
num_classes = len(class_names)
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data
# #### Todo, create a code to visualize one instance of all the nine classes present in the dataset

# %%
plt.figure(figsize=(15, 15))
visited = []
visited_all = False
j = 0

for image, label in train_ds.take(50):
  if visited_all:
    break
  for i in range(len(class_names)):
    if len(visited) == 9:
      visited_all = True
      break
    if class_names[label[i]] in visited:
      continue
    else:
      ax = plt.subplot(3, 3, j+1)
      j+=1
      plt.imshow(image[i].numpy().astype('uint8'))
      plt.title(class_names[label[i]])
      plt.axis('off')
      visited.append(class_names[label[i]])

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
print(type(train_ds), "\n", type(test_ds))
# Out:
# <class 'tensorflow.python.data.ops.dataset_ops.PrefetchDataset'>
#  <class 'tensorflow.python.data.ops.dataset_ops.BatchDataset'>

# %% [markdown]
# ### Create the model
# #### Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
def model1():
  # create model
  model = Sequential()
  model.add(Rescaling(scale=1./255, input_shape=(img_height, img_width, 3)))

  model.add(Conv2D(16, (3, 3), padding='same', activation='relu'))
  model.add(Conv2D(16, (3, 3), activation='relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  
  model.add(Conv2D(32, (3, 3), padding='same', activation='relu'))
  model.add(Conv2D(32, (3, 3), activation='relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
    
  model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
  model.add(Conv2D(64, (3, 3), activation='relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))

  model.add(Flatten())
  model.add(Dense(256, activation='relu'))
  model.add(Dense(64, activation='relu'))
  model.add(Dense(num_classes, activation='softmax'))
  return model

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
## Creating Model
model1 = model1()

# %%
# View the summary of all layers
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 16)      448
#
#  conv2d_1 (Conv2D)           (None, 178, 178, 16)      2320
#
#  max_pooling2d (MaxPooling2D  (None, 89, 89, 16)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 89, 89, 32)        4640
#
#  conv2d_3 (Conv2D)           (None, 87, 87, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 43, 43, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 43, 43, 64)        18496
#
#  conv2d_5 (Conv2D)           (None, 41, 41, 64)        36928
#
#  max_pooling2d_2 (MaxPooling  (None, 20, 20, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 25600)             0
#
#  dense (Dense)               (None, 256)               6553856
#
#  dense_1 (Dense)             (None, 64)                16448
#
#  dense_2 (Dense)             (None, 9)                 585
#
# =================================================================
# Total params: 6,642,969
# Trainable params: 6,642,969
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# <font color="dark-blue">
# <p> Total params: 6,642,969
# <p> Trainable params: 6,642,969
# <p> Non-trainable params: 0

# %%
# Compile model
model1.compile(adam_v2.Adam(learning_rate = 0.0005), loss='SparseCategoricalCrossentropy', metrics=['accuracy', 'mse'])

# %% [markdown]
# ### Train the model

# %%
epochs = 30
history1 = model1.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 56/56 [==============================] - 297s 1s/step - loss: 1.9906 - accuracy: 0.2360 - mse: 18.0850 - val_loss: 1.8373 - val_accuracy: 0.3110 - val_mse: 18.4576
# Epoch 2/30
# 56/56 [==============================] - 3s 50ms/step - loss: 1.7640 - accuracy: 0.3432 - mse: 18.0915 - val_loss: 1.7496 - val_accuracy: 0.3758 - val_mse: 18.4609
# Epoch 3/30
# 56/56 [==============================] - 3s 54ms/step - loss: 1.6085 - accuracy: 0.4325 - mse: 18.0977 - val_loss: 1.6204 - val_accuracy: 0.4228 - val_mse: 18.4665
# Epoch 4/30
# 56/56 [==============================] - 3s 50ms/step - loss: 1.5510 - accuracy: 0.4548 - mse: 18.1002 - val_loss: 1.5784 - val_accuracy: 0.4676 - val_mse: 18.4671
# Epoch 5/30
# 56/56 [==============================] - 3s 49ms/step - loss: 1.4375 - accuracy: 0.5078 - mse: 18.1043 - val_loss: 1.5193 - val_accuracy: 0.4698 - val_mse: 18.4759
# Epoch 6/30
# 56/56 [==============================] - 3s 48ms/step - loss: 1.3756 - accuracy: 0.5212 - mse: 18.1072 - val_loss: 1.4318 - val_accuracy: 0.5213 - val_mse: 18.4898
# Epoch 7/30
# 56/56 [==============================] - 3s 48ms/step - loss: 1.2890 - accuracy: 0.5474 - mse: 18.1116 - val_loss: 1.3778 - val_accuracy: 0.5280 - val_mse: 18.4806
# Epoch 8/30
# 56/56 [==============================] - 3s 49ms/step - loss: 1.2764 - accuracy: 0.5525 - mse: 18.1120 - val_loss: 1.3838 - val_accuracy: 0.5347 - val_mse: 18.4838
# Epoch 9/30
# 56/56 [==============================] - 3s 48ms/step - loss: 1.2033 - accuracy: 0.5580 - mse: 18.1140 - val_loss: 1.3581 - val_accuracy: 0.5324 - val_mse: 18.4818
# Epoch 10/30
# 56/56 [==============================] - 3s 49ms/step - loss: 1.1977 - accuracy: 0.5698 - mse: 18.1153 - val_loss: 1.4266 - val_accuracy: 0.5190 - val_mse: 18.4916
# Epoch 11/30
# 56/56 [==============================] - 3s 49ms/step - loss: 1.1591 - accuracy: 0.5742 - mse: 18.1175 - val_loss: 1.3444 - val_accuracy: 0.5213 - val_mse: 18.4870
# Epoch 12/30
# 56/56 [==============================] - 3s 49ms/step - loss: 1.1312 - accuracy: 0.5865 - mse: 18.1185 - val_loss: 1.5149 - val_accuracy: 0.4855 - val_mse: 18.4880
# Epoch 13/30
# 56/56 [==============================] - 3s 49ms/step - loss: 1.0946 - accuracy: 0.6066 - mse: 18.1191 - val_loss: 1.4301 - val_accuracy: 0.5011 - val_mse: 18.4890
# Epoch 14/30
# 56/56 [==============================] - 3s 49ms/step - loss: 0.9908 - accuracy: 0.6356 - mse: 18.1228 - val_loss: 1.4629 - val_accuracy: 0.5324 - val_mse: 18.4965
# Epoch 15/30
# 56/56 [==============================] - 3s 49ms/step - loss: 0.9459 - accuracy: 0.6579 - mse: 18.1269 - val_loss: 1.6989 - val_accuracy: 0.5168 - val_mse: 18.4967
# Epoch 16/30
# 56/56 [==============================] - 3s 49ms/step - loss: 0.9512 - accuracy: 0.6652 - mse: 18.1250 - val_loss: 1.8056 - val_accuracy: 0.5280 - val_mse: 18.5002
# Epoch 17/30
# 56/56 [==============================] - 3s 49ms/step - loss: 0.8945 - accuracy: 0.6702 - mse: 18.1291 - val_loss: 1.4133 - val_accuracy: 0.5369 - val_mse: 18.4937
# Epoch 18/30
# 56/56 [==============================] - 3s 50ms/step - loss: 0.8167 - accuracy: 0.6964 - mse: 18.1319 - val_loss: 1.7528 - val_accuracy: 0.4944 - val_mse: 18.4940
# Epoch 19/30
# 56/56 [==============================] - 3s 50ms/step - loss: 0.7698 - accuracy: 0.7121 - mse: 18.1341 - val_loss: 1.7902 - val_accuracy: 0.5391 - val_mse: 18.5042
# Epoch 20/30
# 56/56 [==============================] - 3s 50ms/step - loss: 0.6859 - accuracy: 0.7483 - mse: 18.1377 - val_loss: 1.8721 - val_accuracy: 0.5302 - val_mse: 18.5095
# Epoch 21/30
# 56/56 [==============================] - 3s 50ms/step - loss: 0.6306 - accuracy: 0.7589 - mse: 18.1413 - val_loss: 2.0076 - val_accuracy: 0.4922 - val_mse: 18.5071
# Epoch 22/30
# 56/56 [==============================] - 3s 51ms/step - loss: 0.5897 - accuracy: 0.7729 - mse: 18.1428 - val_loss: 2.1204 - val_accuracy: 0.5391 - val_mse: 18.5158
# Epoch 23/30
# 56/56 [==============================] - 3s 51ms/step - loss: 0.5341 - accuracy: 0.8058 - mse: 18.1464 - val_loss: 2.2127 - val_accuracy: 0.5324 - val_mse: 18.5151
# Epoch 24/30
# 56/56 [==============================] - 3s 51ms/step - loss: 0.4554 - accuracy: 0.8359 - mse: 18.1499 - val_loss: 1.9567 - val_accuracy: 0.5123 - val_mse: 18.5098
# Epoch 25/30
# 56/56 [==============================] - 3s 51ms/step - loss: 0.3961 - accuracy: 0.8493 - mse: 18.1532 - val_loss: 2.5723 - val_accuracy: 0.5101 - val_mse: 18.5177
# Epoch 26/30
# 56/56 [==============================] - 3s 51ms/step - loss: 0.4204 - accuracy: 0.8398 - mse: 18.1529 - val_loss: 3.1763 - val_accuracy: 0.4922 - val_mse: 18.5214
# Epoch 27/30
# 56/56 [==============================] - 3s 51ms/step - loss: 0.3906 - accuracy: 0.8549 - mse: 18.1537 - val_loss: 2.8227 - val_accuracy: 0.5101 - val_mse: 18.5212
# Epoch 28/30
# 56/56 [==============================] - 3s 51ms/step - loss: 0.3443 - accuracy: 0.8644 - mse: 18.1566 - val_loss: 3.0233 - val_accuracy: 0.4855 - val_mse: 18.5229
# Epoch 29/30
# 56/56 [==============================] - 3s 51ms/step - loss: 0.3678 - accuracy: 0.8516 - mse: 18.1562 - val_loss: 2.9026 - val_accuracy: 0.4609 - val_mse: 18.5107
# Epoch 30/30
# 56/56 [==============================] - 3s 52ms/step - loss: 0.2967 - accuracy: 0.8828 - mse: 18.1582 - val_loss: 3.0276 - val_accuracy: 0.5034 - val_mse: 18.5271

# %% [markdown]
# ### Visualizing training results

# %%
history= history1
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(14, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
# plotting the model layers 
plot_model(model1, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
print("Printing train loss and accuracy")
score1_train = model1.evaluate(train_ds, verbose=1)
print("Printing validation loss and accuracy")
score1_val = model1.evaluate(val_ds, verbose=1)
print("Printing test loss and accuracy")
score1_test = model1.evaluate(test_ds)
# Out:
# Printing train loss and accuracy
# 56/56 [==============================] - 1s 20ms/step - loss: 0.1973 - accuracy: 0.9202 - mse: 18.1659
# Printing validation loss and accuracy
# 14/14 [==============================] - 0s 19ms/step - loss: 3.0276 - accuracy: 0.5034 - mse: 18.5271
# Printing test loss and accuracy
# 1/1 [==============================] - 28s 28s/step - loss: 6.9115 - accuracy: 0.3051 - mse: 15.9906

# %% [markdown]
# <font color="darkblue">#### After 7th epoch, the model starts overfitting, subsequent result <p> </font>
# <font color="darkblue">#### The training accuracy significantly increases and the test decreases. </font>

# %% [markdown]
# ### We added Dropout and BatchNormalization()
#
# - The final train accuracy is 0.8259
# - Validation accuracy is 0.5123
# - The test accuracy is 0.3475

# %% [markdown]
# ## Model 2: with BatchNormalization() and Dropout()

# %%
def model_2():
  # create model
  model = Sequential()
  model.add(Rescaling(scale=1./255, input_shape=(img_height, img_width, 3)))

  model.add(Conv2D(16, (3, 3), padding='same', activation='relu'))
  model.add(BatchNormalization())
  model.add(Conv2D(16, (3, 3), activation='relu'))
  model.add(BatchNormalization())
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(0.20))
  
  model.add(Conv2D(32, (3, 3), padding='same', activation='relu'))
  model.add(BatchNormalization())
  model.add(Conv2D(32, (3, 3), activation='relu'))
  model.add(BatchNormalization())
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(0.25))
    
  model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
  model.add(BatchNormalization())
  model.add(Conv2D(64, (3, 3), activation='relu'))
  model.add(BatchNormalization())
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(0.30))

  model.add(Flatten())
  model.add(Dense(256, activation='relu'))
  model.add(Dropout(0.40))
  model.add(Dense(128, activation='relu'))
  model.add(Dropout(0.30))
  model.add(Dense(64, activation='relu'))
  model.add(Dropout(0.30))
  model.add(Dense(num_classes, activation='softmax'))

  return model

# %%
## Creating model2
model_2 = model_2()

# %%
## View the summary of all layers
model_2.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_3 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_18 (Conv2D)          (None, 180, 180, 16)      448
#
#  batch_normalization_12 (Bat  (None, 180, 180, 16)     64
#  chNormalization)
#
#  conv2d_19 (Conv2D)          (None, 178, 178, 16)      2320
#
#  batch_normalization_13 (Bat  (None, 178, 178, 16)     64
#  chNormalization)
#
#  max_pooling2d_9 (MaxPooling  (None, 89, 89, 16)       0
#  2D)
#
#  dropout_12 (Dropout)        (None, 89, 89, 16)        0
#
#  conv2d_20 (Conv2D)          (None, 89, 89, 32)        4640
#
#  batch_normalization_14 (Bat  (None, 89, 89, 32)       128
#  chNormalization)
#
#  conv2d_21 (Conv2D)          (None, 87, 87, 32)        9248
#
#  batch_normalization_15 (Bat  (None, 87, 87, 32)       128
#  chNormalization)
#
#  max_pooling2d_10 (MaxPoolin  (None, 43, 43, 32)       0
#  g2D)
#
#  dropout_13 (Dropout)        (None, 43, 43, 32)        0
#
#  conv2d_22 (Conv2D)          (None, 43, 43, 64)        18496
#
#  batch_normalization_16 (Bat  (None, 43, 43, 64)       256
#  chNormalization)
#
#  conv2d_23 (Conv2D)          (None, 41, 41, 64)        36928
#
#  batch_normalization_17 (Bat  (None, 41, 41, 64)       256
#  chNormalization)
#
#  max_pooling2d_11 (MaxPoolin  (None, 20, 20, 64)       0
#  g2D)
#
#  dropout_14 (Dropout)        (None, 20, 20, 64)        0
#
#  flatten_3 (Flatten)         (None, 25600)             0
#
#  dense_11 (Dense)            (None, 256)               6553856
#
#  dropout_15 (Dropout)        (None, 256)               0
#
#  dense_12 (Dense)            (None, 128)               32896
#
#  dropout_16 (Dropout)        (None, 128)               0
#
#  dense_13 (Dense)            (None, 64)                8256
#
#  dropout_17 (Dropout)        (None, 64)                0
#
#  dense_14 (Dense)            (None, 9)                 585
#
# =================================================================
# Total params: 6,668,569
# Trainable params: 6,668,121
# Non-trainable params: 448
# _________________________________________________________________

# %% [markdown]
# <font color="darkblue">
# - Total params: 6,668,569
# - Trainable params: 6,668,121
# - Non-trainable params: 448
# </font>

# %%
# Compile model
model_2.compile(adam_v2.Adam(learning_rate = 0.0001), loss='SparseCategoricalCrossentropy', metrics=['accuracy', 'mse'])

# %% [markdown]
# ### Train the model

# %%
epochs = 30
history2 = model_2.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 56/56 [==============================] - 5s 69ms/step - loss: 2.6058 - accuracy: 0.2020 - mse: 18.0999 - val_loss: 2.1149 - val_accuracy: 0.1790 - val_mse: 18.4517
# Epoch 2/30
# 56/56 [==============================] - 4s 63ms/step - loss: 2.1174 - accuracy: 0.2109 - mse: 18.0875 - val_loss: 2.0966 - val_accuracy: 0.1767 - val_mse: 18.4551
# Epoch 3/30
# 56/56 [==============================] - 4s 64ms/step - loss: 2.0339 - accuracy: 0.2388 - mse: 18.0883 - val_loss: 2.1209 - val_accuracy: 0.1521 - val_mse: 18.4599
# Epoch 4/30
# 56/56 [==============================] - 4s 64ms/step - loss: 1.9600 - accuracy: 0.2773 - mse: 18.0903 - val_loss: 2.1106 - val_accuracy: 0.1588 - val_mse: 18.4631
# Epoch 5/30
# 56/56 [==============================] - 4s 64ms/step - loss: 1.9650 - accuracy: 0.2946 - mse: 18.0921 - val_loss: 2.1236 - val_accuracy: 0.1924 - val_mse: 18.4648
# Epoch 6/30
# 56/56 [==============================] - 4s 64ms/step - loss: 1.9085 - accuracy: 0.2997 - mse: 18.0924 - val_loss: 2.1320 - val_accuracy: 0.2215 - val_mse: 18.4683
# Epoch 7/30
# 56/56 [==============================] - 4s 64ms/step - loss: 1.8780 - accuracy: 0.3538 - mse: 18.0951 - val_loss: 2.1051 - val_accuracy: 0.2528 - val_mse: 18.4731
# Epoch 8/30
# 56/56 [==============================] - 4s 64ms/step - loss: 1.8228 - accuracy: 0.3404 - mse: 18.0958 - val_loss: 2.2637 - val_accuracy: 0.2170 - val_mse: 18.4807
# Epoch 9/30
# 56/56 [==============================] - 4s 64ms/step - loss: 1.8001 - accuracy: 0.3504 - mse: 18.0946 - val_loss: 2.3118 - val_accuracy: 0.2729 - val_mse: 18.4880
# Epoch 10/30
# 56/56 [==============================] - 4s 65ms/step - loss: 1.7521 - accuracy: 0.3856 - mse: 18.0986 - val_loss: 1.9715 - val_accuracy: 0.3535 - val_mse: 18.4811
# Epoch 11/30
# 56/56 [==============================] - 4s 64ms/step - loss: 1.7134 - accuracy: 0.3823 - mse: 18.0986 - val_loss: 1.8623 - val_accuracy: 0.4027 - val_mse: 18.4842
# Epoch 12/30
# 56/56 [==============================] - 4s 65ms/step - loss: 1.6882 - accuracy: 0.4068 - mse: 18.0997 - val_loss: 1.7540 - val_accuracy: 0.4430 - val_mse: 18.4851
# Epoch 13/30
# 56/56 [==============================] - 4s 65ms/step - loss: 1.6683 - accuracy: 0.4135 - mse: 18.1024 - val_loss: 1.6994 - val_accuracy: 0.4452 - val_mse: 18.4882
# Epoch 14/30
# 56/56 [==============================] - 4s 65ms/step - loss: 1.6517 - accuracy: 0.4241 - mse: 18.1016 - val_loss: 1.8143 - val_accuracy: 0.4295 - val_mse: 18.4953
# Epoch 15/30
# 56/56 [==============================] - 4s 65ms/step - loss: 1.6218 - accuracy: 0.4263 - mse: 18.1040 - val_loss: 1.7512 - val_accuracy: 0.4743 - val_mse: 18.4904
# Epoch 16/30
# 56/56 [==============================] - 4s 65ms/step - loss: 1.5598 - accuracy: 0.4520 - mse: 18.1052 - val_loss: 1.6704 - val_accuracy: 0.4474 - val_mse: 18.4908
# Epoch 17/30
# 56/56 [==============================] - 4s 65ms/step - loss: 1.5602 - accuracy: 0.4531 - mse: 18.1057 - val_loss: 1.6310 - val_accuracy: 0.4899 - val_mse: 18.4866
# Epoch 18/30
# 56/56 [==============================] - 4s 65ms/step - loss: 1.4605 - accuracy: 0.4833 - mse: 18.1081 - val_loss: 1.5660 - val_accuracy: 0.5145 - val_mse: 18.4875
# Epoch 19/30
# 56/56 [==============================] - 4s 65ms/step - loss: 1.4807 - accuracy: 0.4883 - mse: 18.1082 - val_loss: 1.5441 - val_accuracy: 0.5190 - val_mse: 18.4902
# Epoch 20/30
# 56/56 [==============================] - 4s 65ms/step - loss: 1.4070 - accuracy: 0.5145 - mse: 18.1097 - val_loss: 1.6177 - val_accuracy: 0.5257 - val_mse: 18.4952
# Epoch 21/30
# 56/56 [==============================] - 4s 65ms/step - loss: 1.4385 - accuracy: 0.4916 - mse: 18.1100 - val_loss: 1.5624 - val_accuracy: 0.5324 - val_mse: 18.4966
# Epoch 22/30
# 56/56 [==============================] - 4s 65ms/step - loss: 1.3960 - accuracy: 0.5089 - mse: 18.1113 - val_loss: 1.5993 - val_accuracy: 0.5123 - val_mse: 18.4973
# Epoch 23/30
# 56/56 [==============================] - 4s 65ms/step - loss: 1.3759 - accuracy: 0.5285 - mse: 18.1119 - val_loss: 1.5407 - val_accuracy: 0.5257 - val_mse: 18.5016
# Epoch 24/30
# 56/56 [==============================] - 4s 65ms/step - loss: 1.3247 - accuracy: 0.5430 - mse: 18.1138 - val_loss: 1.6189 - val_accuracy: 0.5369 - val_mse: 18.5031
# Epoch 25/30
# 56/56 [==============================] - 4s 65ms/step - loss: 1.3048 - accuracy: 0.5592 - mse: 18.1162 - val_loss: 1.5532 - val_accuracy: 0.5235 - val_mse: 18.5032
# Epoch 26/30
# 56/56 [==============================] - 4s 65ms/step - loss: 1.2936 - accuracy: 0.5458 - mse: 18.1154 - val_loss: 1.6471 - val_accuracy: 0.5190 - val_mse: 18.5011
# Epoch 27/30
# 56/56 [==============================] - 4s 66ms/step - loss: 1.2483 - accuracy: 0.5592 - mse: 18.1183 - val_loss: 1.5398 - val_accuracy: 0.5638 - val_mse: 18.5024
# Epoch 28/30
# 56/56 [==============================] - 4s 66ms/step - loss: 1.2326 - accuracy: 0.5781 - mse: 18.1178 - val_loss: 1.7216 - val_accuracy: 0.5056 - val_mse: 18.5049
# Epoch 29/30
# 56/56 [==============================] - 4s 71ms/step - loss: 1.1921 - accuracy: 0.5776 - mse: 18.1195 - val_loss: 1.6286 - val_accuracy: 0.5593 - val_mse: 18.5074
# Epoch 30/30
# 56/56 [==============================] - 4s 66ms/step - loss: 1.1697 - accuracy: 0.5787 - mse: 18.1209 - val_loss: 1.6594 - val_accuracy: 0.5347 - val_mse: 18.5072

# %% [markdown]
# ### Visualizing training results

# %%
history = history2
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(14, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy (Model2)')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss (Model2)')
plt.show()

# %%
# plotting the model layers 
plot_model(model2, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
print("Printing train loss and accuracy")
score1_train = model_2.evaluate(train_ds, verbose=1)
print("Printing validation loss and accuracy")
score1_val = model_2.evaluate(val_ds, verbose=1)
print("Printing test loss and accuracy")
score1_test = model_2.evaluate(test_ds)
# Out:
# Printing train loss and accuracy
# 56/56 [==============================] - 1s 18ms/step - loss: 1.2135 - accuracy: 0.6071 - mse: 18.1366
# Printing validation loss and accuracy
# 14/14 [==============================] - 0s 16ms/step - loss: 1.6594 - accuracy: 0.5347 - mse: 18.5072
# Printing test loss and accuracy
# 1/1 [==============================] - 4s 4s/step - loss: 2.9073 - accuracy: 0.3051 - mse: 15.9725

# %% [markdown]
# #### Now the model looks good but the accuracy is really low.

# %% [markdown]
# ### Reason for low accuract is less variety of data, and we have less data.
# #### Augment the dataset.
# **We can see that:**
# - The final train accuracy is 0.4927
# - Validation accuracy is 0.4497
# - The test accuracy is 0.3136

# %% [markdown]
# #### For the next model we can augment the images and see how much it can improve.

# %% [markdown]
# ## Model 3: Augmenting data

# %%
# creating keras augment varaiable
data_aug = Sequential([
                      layers.experimental.preprocessing.RandomFlip(mode="horizontal_and_vertical", input_shape=(img_height,img_width,3)),
                    #  layers.experimental.preprocessing.RandomTranslation(height_factor=(0.3, 0.3), width_factor=(0.3, 0.3), fill_mode="reflect", interpolation="bilinear",),
                      layers.experimental.preprocessing.RandomRotation(factor=0.2, fill_mode='reflect'),
                      layers.experimental.preprocessing.RandomZoom(height_factor=(0.3, 0.3), width_factor=(0.3, 0.3), fill_mode='reflect')
])

# %% [markdown]
# ## Visulizing Augumentation data

# %%
visited = []
visited_all = False
plot_idx = 0
num_classes = len(class_names)
plt.figure(figsize=(10,40))

for image, label in train_ds.take(20):
  if visited_all:
    print(visited)
    break
  for i in range(num_classes):
    if len(visited) == num_classes:
      visited_all = True
      break

    if class_names[label[i]] in visited:
      continue
    else:
      plt.subplot(num_classes,2,plot_idx+1)
      plt.imshow(image[i].numpy().astype("uint8"))
      plt.title("Original_"+class_names[label[i]])
      plot_idx+=1

      plt.subplot(num_classes,2,plot_idx+1)
      aug_img=data_aug(image)
      plt.imshow(aug_img[i].numpy().astype("uint8"))
      plt.title("Augmented_"+class_names[label[i]])
      plot_idx+=1

      visited.append(class_names[label[i]])
# Out:
# ['pigmented benign keratosis', 'melanoma', 'basal cell carcinoma', 'squamous cell carcinoma', 'seborrheic keratosis', 'nevus', 'dermatofibroma', 'actinic keratosis', 'vascular lesion']

# %% [markdown]
# ### We can see that each image is augmented, the left is the original, and the right is the augmented image. And you can see the difference.

# %% [markdown]
# ### Defining model 3

# %%
def model_3():
  model = Sequential()
  model.add(data_aug)
  model.add(Rescaling(scale=1./255, input_shape=(img_height, img_width, 3)))

  model.add(Conv2D(16, (3, 3), padding='same', activation='relu'))
  model.add(BatchNormalization())
  model.add(Conv2D(16, (3, 3), activation='relu'))
  model.add(BatchNormalization())
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(0.20))
  
  model.add(Conv2D(32, (3, 3), padding='same', activation='relu'))
  model.add(BatchNormalization())
  model.add(Conv2D(32, (3, 3), activation='relu'))
  model.add(BatchNormalization())
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(0.25))
    
  model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
  model.add(BatchNormalization())
  model.add(Conv2D(64, (3, 3), activation='relu'))
  model.add(BatchNormalization())
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(0.30))

  model.add(Flatten())
  model.add(Dense(256, activation='relu'))
  model.add(Dropout(0.40))
  model.add(Dense(128, activation='relu'))
  model.add(Dropout(0.30))
  model.add(Dense(64, activation='relu'))
  model.add(Dropout(0.30))
  model.add(Dense(num_classes, activation='softmax'))

  return model

# %%
## Creating Model 3
model_3 = model_3()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-d01459854238> in <module>
#       1 ## Creating Model 3
# ----> 2 model_3 = model_3()
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py in _split_out_first_arg(self, args, kwargs)
#    3099     else:
#    3100       raise ValueError(
# -> 3101           'The first argument to `Layer.call` must always be passed.')
#    3102     return inputs, args, kwargs
#    3103
#
# ValueError: The first argument to `Layer.call` must always be passed.

# %%
## View the summary of all layers
model_3.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_4 (Sequential)   (None, 180, 180, 3)       0
#
#  rescaling_4 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_24 (Conv2D)          (None, 180, 180, 16)      448
#
#  batch_normalization_18 (Bat  (None, 180, 180, 16)     64
#  chNormalization)
#
#  conv2d_25 (Conv2D)          (None, 178, 178, 16)      2320
#
#  batch_normalization_19 (Bat  (None, 178, 178, 16)     64
#  chNormalization)
#
#  max_pooling2d_12 (MaxPoolin  (None, 89, 89, 16)       0
#  g2D)
#
#  dropout_18 (Dropout)        (None, 89, 89, 16)        0
#
#  conv2d_26 (Conv2D)          (None, 89, 89, 32)        4640
#
#  batch_normalization_20 (Bat  (None, 89, 89, 32)       128
#  chNormalization)
#
#  conv2d_27 (Conv2D)          (None, 87, 87, 32)        9248
#
#  batch_normalization_21 (Bat  (None, 87, 87, 32)       128
#  chNormalization)
#
#  max_pooling2d_13 (MaxPoolin  (None, 43, 43, 32)       0
#  g2D)
#
#  dropout_19 (Dropout)        (None, 43, 43, 32)        0
#
#  conv2d_28 (Conv2D)          (None, 43, 43, 64)        18496
#
#  batch_normalization_22 (Bat  (None, 43, 43, 64)       256
#  chNormalization)
#
#  conv2d_29 (Conv2D)          (None, 41, 41, 64)        36928
#
#  batch_normalization_23 (Bat  (None, 41, 41, 64)       256
#  chNormalization)
#
#  max_pooling2d_14 (MaxPoolin  (None, 20, 20, 64)       0
#  g2D)
#
#  dropout_20 (Dropout)        (None, 20, 20, 64)        0
#
#  flatten_4 (Flatten)         (None, 25600)             0
#
#  dense_15 (Dense)            (None, 256)               6553856
#
#  dropout_21 (Dropout)        (None, 256)               0
#
#  dense_16 (Dense)            (None, 128)               32896
#
#  dropout_22 (Dropout)        (None, 128)               0
#
#  dense_17 (Dense)            (None, 64)                8256
#
#  dropout_23 (Dropout)        (None, 64)                0
#
#  dense_18 (Dense)            (None, 9)                 585
#
# =================================================================
# Total params: 6,668,569
# Trainable params: 6,668,121
# Non-trainable params: 448
# _________________________________________________________________

# %%
## Compile model
model_3.compile(adam_v2.Adam(learning_rate = 0.0001), loss='SparseCategoricalCrossentropy', metrics=['accuracy', 'mse'])

# %% [markdown]
# ### Train the model

# %%
epochs = 30
history3 = model_3.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 56/56 [==============================] - 7s 89ms/step - loss: 2.7017 - accuracy: 0.2104 - mse: 18.1030 - val_loss: 2.5577 - val_accuracy: 0.0626 - val_mse: 18.4548
# Epoch 2/30
# 56/56 [==============================] - 5s 84ms/step - loss: 2.0708 - accuracy: 0.2584 - mse: 18.0905 - val_loss: 2.7558 - val_accuracy: 0.2058 - val_mse: 18.4608
# Epoch 3/30
# 56/56 [==============================] - 5s 86ms/step - loss: 1.9840 - accuracy: 0.2885 - mse: 18.0901 - val_loss: 3.0540 - val_accuracy: 0.2058 - val_mse: 18.4741
# Epoch 4/30
# 56/56 [==============================] - 5s 92ms/step - loss: 1.9785 - accuracy: 0.3030 - mse: 18.0921 - val_loss: 3.1791 - val_accuracy: 0.2058 - val_mse: 18.4852
# Epoch 5/30
# 56/56 [==============================] - 5s 85ms/step - loss: 1.9182 - accuracy: 0.3359 - mse: 18.0935 - val_loss: 2.9142 - val_accuracy: 0.2170 - val_mse: 18.4792
# Epoch 6/30
# 56/56 [==============================] - 5s 85ms/step - loss: 1.8580 - accuracy: 0.3504 - mse: 18.0977 - val_loss: 2.7035 - val_accuracy: 0.2371 - val_mse: 18.4791
# Epoch 7/30
# 56/56 [==============================] - 5s 84ms/step - loss: 1.8319 - accuracy: 0.3627 - mse: 18.0958 - val_loss: 2.6031 - val_accuracy: 0.2506 - val_mse: 18.4811
# Epoch 8/30
# 56/56 [==============================] - 5s 84ms/step - loss: 1.8039 - accuracy: 0.3895 - mse: 18.0991 - val_loss: 2.4528 - val_accuracy: 0.2662 - val_mse: 18.4849
# Epoch 9/30
# 56/56 [==============================] - 5s 84ms/step - loss: 1.7651 - accuracy: 0.4040 - mse: 18.0988 - val_loss: 2.4084 - val_accuracy: 0.2931 - val_mse: 18.4912
# Epoch 10/30
# 56/56 [==============================] - 5s 84ms/step - loss: 1.6988 - accuracy: 0.4230 - mse: 18.1002 - val_loss: 1.9179 - val_accuracy: 0.3982 - val_mse: 18.4837
# Epoch 11/30
# 56/56 [==============================] - 5s 84ms/step - loss: 1.7011 - accuracy: 0.4191 - mse: 18.1021 - val_loss: 1.9169 - val_accuracy: 0.3960 - val_mse: 18.4855
# Epoch 12/30
# 56/56 [==============================] - 5s 85ms/step - loss: 1.6690 - accuracy: 0.4314 - mse: 18.1029 - val_loss: 2.0241 - val_accuracy: 0.3937 - val_mse: 18.4918
# Epoch 13/30
# 56/56 [==============================] - 5s 96ms/step - loss: 1.6455 - accuracy: 0.4459 - mse: 18.1031 - val_loss: 1.9215 - val_accuracy: 0.3937 - val_mse: 18.4958
# Epoch 14/30
# 56/56 [==============================] - 5s 85ms/step - loss: 1.6477 - accuracy: 0.4542 - mse: 18.1047 - val_loss: 1.9188 - val_accuracy: 0.4183 - val_mse: 18.4900
# Epoch 15/30
# 56/56 [==============================] - 5s 85ms/step - loss: 1.6131 - accuracy: 0.4593 - mse: 18.1033 - val_loss: 1.6253 - val_accuracy: 0.4653 - val_mse: 18.4870
# Epoch 16/30
# 56/56 [==============================] - 5s 85ms/step - loss: 1.6281 - accuracy: 0.4537 - mse: 18.1038 - val_loss: 1.5826 - val_accuracy: 0.4698 - val_mse: 18.4831
# Epoch 17/30
# 56/56 [==============================] - 5s 85ms/step - loss: 1.5557 - accuracy: 0.4844 - mse: 18.1069 - val_loss: 1.5486 - val_accuracy: 0.4922 - val_mse: 18.4863
# Epoch 18/30
# 56/56 [==============================] - 5s 85ms/step - loss: 1.5566 - accuracy: 0.4771 - mse: 18.1071 - val_loss: 1.7021 - val_accuracy: 0.4497 - val_mse: 18.4885
# Epoch 19/30
# 56/56 [==============================] - 5s 85ms/step - loss: 1.5429 - accuracy: 0.4967 - mse: 18.1086 - val_loss: 1.8907 - val_accuracy: 0.4452 - val_mse: 18.4949
# Epoch 20/30
# 56/56 [==============================] - 5s 86ms/step - loss: 1.5348 - accuracy: 0.4844 - mse: 18.1081 - val_loss: 2.1224 - val_accuracy: 0.4004 - val_mse: 18.4982
# Epoch 21/30
# 56/56 [==============================] - 5s 85ms/step - loss: 1.5391 - accuracy: 0.4877 - mse: 18.1087 - val_loss: 1.8566 - val_accuracy: 0.4452 - val_mse: 18.4942
# Epoch 22/30
# 56/56 [==============================] - 5s 85ms/step - loss: 1.5695 - accuracy: 0.4877 - mse: 18.1078 - val_loss: 1.9349 - val_accuracy: 0.4206 - val_mse: 18.4964
# Epoch 23/30
# 56/56 [==============================] - 5s 85ms/step - loss: 1.5278 - accuracy: 0.4955 - mse: 18.1095 - val_loss: 1.7095 - val_accuracy: 0.4787 - val_mse: 18.4902
# Epoch 24/30
# 56/56 [==============================] - 5s 86ms/step - loss: 1.5109 - accuracy: 0.5022 - mse: 18.1077 - val_loss: 1.5749 - val_accuracy: 0.5011 - val_mse: 18.4913
# Epoch 25/30
# 56/56 [==============================] - 5s 86ms/step - loss: 1.4961 - accuracy: 0.4983 - mse: 18.1090 - val_loss: 1.6550 - val_accuracy: 0.4832 - val_mse: 18.4943
# Epoch 26/30
# 56/56 [==============================] - 5s 85ms/step - loss: 1.4707 - accuracy: 0.5011 - mse: 18.1093 - val_loss: 1.8842 - val_accuracy: 0.4430 - val_mse: 18.4981
# Epoch 27/30
# 56/56 [==============================] - 5s 86ms/step - loss: 1.4846 - accuracy: 0.5067 - mse: 18.1109 - val_loss: 1.9198 - val_accuracy: 0.4318 - val_mse: 18.5003
# Epoch 28/30
# 56/56 [==============================] - 5s 85ms/step - loss: 1.4365 - accuracy: 0.5279 - mse: 18.1108 - val_loss: 1.7009 - val_accuracy: 0.4787 - val_mse: 18.4974
# Epoch 29/30
# 56/56 [==============================] - 5s 85ms/step - loss: 1.4648 - accuracy: 0.5039 - mse: 18.1113 - val_loss: 1.7877 - val_accuracy: 0.5056 - val_mse: 18.5006
# Epoch 30/30
# 56/56 [==============================] - 5s 85ms/step - loss: 1.4729 - accuracy: 0.5078 - mse: 18.1101 - val_loss: 1.8696 - val_accuracy: 0.4698 - val_mse: 18.5004

# %% [markdown]
# ### Visualizing training results

# %%
history = history3
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(14, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy (Model3)')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss (Model3)')
plt.show()

# %%
## Plotting the model layers 
plot_model(model_3, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
print("Printing train loss and accuracy")
score1_train = model_3.evaluate(train_ds, verbose=1)
print("Printing validation loss and accuracy")
score1_val = model_3.evaluate(val_ds, verbose=1)
print("Printing test loss and accuracy")
score1_test = model_3.evaluate(test_ds)
# Out:
# Printing train loss and accuracy
# 56/56 [==============================] - 1s 19ms/step - loss: 1.6701 - accuracy: 0.5128 - mse: 18.1280
# Printing validation loss and accuracy
# 14/14 [==============================] - 0s 16ms/step - loss: 1.8696 - accuracy: 0.4698 - mse: 18.5004
# Printing test loss and accuracy
# 1/1 [==============================] - 4s 4s/step - loss: 2.8682 - accuracy: 0.3305 - mse: 15.9641

# %% [markdown]
# #### Now the model looks good and overfitting is resolved. However, the accuracy is really low.

# %% [markdown]
# #### This is the cause because we don't have much variety of data, and we have fewer data. So we should create more samples for each class to make it less imbalance.
# **We can see that:**
# - The final train accuracy is 0.5128
# - Validation accuracy is 0.4698
# - The test accuracy is 0.3305
#
# ### Compare to the 2nd model, we got better result using Augumentation and preprocessing the image.

# %% [markdown]
# #### For the next model we can augment the images and see how much it can improve.
# - So, we need to rectify the class imbalance.
# - And add some more images so we can get better accuracy.

# %% [markdown]
# #### **Todo:** Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
class_count = []
for i in class_names:
  class_path = pathlib.Path(root_path + "/Train" + "/"+  i)
  count = len(list(class_path.glob('*.jpg')))
  class_count.append(count)

print(class_names, "\n", class_count)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']
#  [114, 376, 95, 438, 357, 462, 77, 181, 139]

# %%
class_data = {"Class Names" : class_names, "Class Count" : class_count}
df_class = pd.DataFrame(class_data)
print(df_class)
# Out:
#                   Class Names  Class Count
# 0           actinic keratosis          114
# 1        basal cell carcinoma          376
# 2              dermatofibroma           95
# 3                    melanoma          438
# 4                       nevus          357
# 5  pigmented benign keratosis          462
# 6        seborrheic keratosis           77
# 7     squamous cell carcinoma          181
# 8             vascular lesion          139

# %% [markdown]
# ## Plotting each class counts using bar graph.

# %%
class_colr = ["#d1a9b9", "#ef970f", "#65afcf", "#b0da13", "#202836", "#748ee0", "#67bfa1", "#8597bb", "#490d91"]

# Figure Size
fig, ax = plt.subplots(figsize =(16, 9))
 
# Horizontal Bar Plot
ax.barh(class_names, class_count, color = class_colr, edgecolor='blue')
 
# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(True)

# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
 
# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)
 
# Add x, y gridlines
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.2)
 
# Show top values
ax.invert_yaxis()
 
# Add annotation to bars
for i in ax.patches:
    plt.text(i.get_width()+3, i.get_y()+0.5,
             str(round((i.get_width()), 2)),
             fontsize = 14, fontweight ='bold',
             color ='grey')
 
# Add Plot Title
ax.set_title('The distribution of classes in the Training Dataset',
             loc ='left', )
size=20
params = {'legend.fontsize': 'large',
          'axes.labelsize': size,
          'axes.titlesize': 25,
          'xtick.labelsize': size*0.75,
          'ytick.labelsize': 25*0.75,
          'axes.titlepad': 15}
plt.rcParams.update(params)


# Show Plot
plt.show()

# source: https://www.geeksforgeeks.org/bar-plot-in-matplotlib/

# %% [markdown]
# <font color="darkblue">
# <p>
#
# ### Some insights:
# <font color="darkblue">
# - Basal cell carcinoma(95) and Seborrheic keratosis(77) have the least samples.
# - Pigmented benign keratosis(462) and Melanoma(438) have the most samples.
# - Actinic keratosis(114), Squamous cell carcinoma(181), Vascular lesion(139), Basal cell carcinoma(95), and Seborrheic keratosis(77) have samples less than **40%** compared to **most samples classes**( Pigmented benign keratosis-462).
#
# #### Because of imbalance classes, we are getting lousy accuracy and model being biased towards the most sample classes.
# <font color="darkblue">
# - So, we need to rectify the class imbalance.
# - And add some more images so we can get better accuracy.
# </font>

# %% [markdown]
# #### **Todo:** Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Augmentor
#   Downloading Augmentor-0.2.10-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (0.16.0)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (7.1.2)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (4.64.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (1.21.6)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.10

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
image_count_train = len(list(dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 0

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
class_count = []

for i in class_names:
  class_path = pathlib.Path(root_path + "/Train" + "/"+  i)
  count = len(list(class_path.glob('*/*.jpg')))
  class_count.append(count)

print(class_names, "\n", class_count)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']
#  [0, 0, 0, 0, 0, 0, 0, 0, 0]

# %%
class_data = {"Class Names" : class_names, "Class Count" : class_count}
df_class = pd.DataFrame(class_data)
print(df_class)
# Out:
#                   Class Names  Class Count
# 0           actinic keratosis            0
# 1        basal cell carcinoma            0
# 2              dermatofibroma            0
# 3                    melanoma            0
# 4                       nevus            0
# 5  pigmented benign keratosis            0
# 6        seborrheic keratosis            0
# 7     squamous cell carcinoma            0
# 8             vascular lesion            0

# %% [markdown]
# ### now we can see that we have added 500 images to each class.

# %%
class_count = []

for i in class_names:
  class_path = pathlib.Path(main_path + "/Train" + "/"+  i)
  count = len(list(class_path.glob('**/*.jpg')))
  class_count.append(count)

print(class_names, "\n", class_count)

# %%
class_data = {"Class Names" : class_names, "Class Count" : class_count}
df_class = pd.DataFrame(class_data)
print(df_class)

# %%
class_colr = ["#d1a9b9", "#ef970f", "#65afcf", "#b0da13", "#202836", "#748ee0", "#67bfa1", "#8597bb", "#490d91"]

# Figure Size
fig, ax = plt.subplots(figsize =(16, 9))
 
# Horizontal Bar Plot
ax.barh(class_names, class_count, color = class_colr, edgecolor='blue')
 
# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(True)

# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
 
# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)
 
# Add x, y gridlines
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.2)
 
# Show top values
ax.invert_yaxis()
 
# Add annotation to bars
for i in ax.patches:
    plt.text(i.get_width()+3, i.get_y()+0.5,
             str(round((i.get_width()), 2)),
             fontsize = 14, fontweight ='bold',
             color ='grey')
 
# Add Plot Title
ax.set_title('The distribution of classes in the Training Dataset',
             loc ='left', )
size=20
params = {'legend.fontsize': 'large',
          'axes.labelsize': size,
          'axes.titlesize': 25,
          'xtick.labelsize': size*0.75,
          'ytick.labelsize': 25*0.75,
          'axes.titlepad': 15}
plt.rcParams.update(params)


# Show Plot
plt.show()

# source: https://www.geeksforgeeks.org/bar-plot-in-matplotlib/

# %% [markdown]
# ### Here, we can see that classes are not too imbalanced, and we can move with this sample counts for each class. And the ratio of imbalance is not high.

# %%
main_path = "/content/gdrive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration"

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### Create a training dataset

# %%
data_dir_train_new = pathlib.Path(main_path + "/Train")

# data_dir_train_new= data_dir_train.glob('*/output/*.jpg')
new_train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train_new,
  seed=123,
  validation_split = 0.2,
  subset = 'training',
  image_size=(img_height, img_width),
  batch_size=batch_size)

# %% [markdown]
# #### Create a validation dataset

# %%
new_val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train_new,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)

# %%
## for test set , creating only 1 batch
data_dir_test_new = pathlib.Path(main_path + "/Test")
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_test_new,
    seed=123,
    batch_size=118,
    image_size=(img_height,img_width)
)

# %%
class_names = new_train_ds.class_names
num_classes = len(class_names)
print(class_names)

# %% [markdown]
# ## Model 4

# %%
def model4():
  # create model
  model = Sequential()
  model.add(Rescaling(scale=1./255, input_shape=(img_height, img_width, 3)))

  model.add(Conv2D(16, (3, 3), padding='same', activation='relu'))
  model.add(BatchNormalization())
  model.add(Conv2D(16, (3, 3), padding='same', activation='relu'))
  model.add(BatchNormalization())
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(0.25))
  
  model.add(Conv2D(32, (3, 3), padding='same', activation='relu'))
  model.add(BatchNormalization())
  model.add(Conv2D(32, (3, 3), padding='same', activation='relu'))
  model.add(BatchNormalization())
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(0.25))
    
  model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
  model.add(BatchNormalization())
  model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
  model.add(BatchNormalization())
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(0.25))
  
  model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
  model.add(BatchNormalization())
  model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
  model.add(BatchNormalization())
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(0.40))

  model.add(Flatten())
  model.add(Dense(256, activation='relu'))
  model.add(Dropout(0.25))
  model.add(Dense(128, activation='relu'))
  model.add(Dropout(0.25))
  model.add(Dense(64, activation='relu'))
  model.add(Dropout(0.30))
  model.add(Dense(num_classes, activation='softmax'))

  return model

# %%
### creating final model
model4 = model4()

# %%
# View the summary of all layers
model4.summary()

# %%
# Compile model
model4.compile(adam_v2.Adam(learning_rate = 0.0001), loss='SparseCategoricalCrossentropy', metrics=['accuracy', 'mse'])

# %% [markdown]
# ### Train the model

# %%
epochs = 50
history4 = model4.fit(
  new_train_ds,
  validation_data=new_val_ds,
  epochs=epochs
)

# %% [markdown]
# ### Visualizing training results

# %%
history = history4
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(14, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy (Model4)')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss (Model4)')
plt.show()

# %%
plot_model(model4, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
print("Printing train loss and accuracy")
score1_train = model4.evaluate(new_train_ds, verbose=1)
print("Printing validation loss and accuracy")
score1_val = model4.evaluate(new_val_ds, verbose=1)
print("Printing test loss and accuracy")
score1_test = model4.evaluate(test_ds)

# %% [markdown]
# #### Now the model looks good and even the accuracy is ok and model didn't overfit.

# %% [markdown]
# #### We can still improve the accuracy, but we need more data. As of now, we have really less data, and even we can augment more data. Here we created only 500 images for each class; in the future, we can create more like 1.5k+.
# **Final model accuracy:**
# - The final train accuracy is 0.9343
# - Validation accuracy is 0.8567
# - The test accuracy is 0.4746

# %% [markdown]
# ### So using augmentation, rebalance, dropout, and batch norm helped reduce the overfitting and improved the model accuracy.
